# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../train.csv')
#df = df.sort_values(by='user_id', ascending=True)
print(df.info())
df = df.sort_values(by='user_id')
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254441 entries, 0 to 1254440
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1254441 non-null  int64
#  1   item_id  1254441 non-null  int64
#  2   rating   1254441 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 28.7 MB
# None
#         user_id  item_id  rating
# 482119        0    15825     5.0
# 482118        0    41241     5.0
# 482117        0    29131     5.0
# 968757        1    14309     5.0
# 968760        1    52670     5.0
# ...         ...      ...     ...
# 640395   192402    39050     5.0
# 640396   192402    44981     4.0
# 640397   192402    42537     5.0
# 640399   192402    42987     5.0
# 640398   192402    26432     5.0
#
# [1254441 rows x 3 columns]

# %%
uid_field, iid_field = 'user_id', 'item_id'

uid_freq = df.groupby(uid_field)[iid_field]
u_i_dict = {}
for u, u_ls in uid_freq:
    u_i_dict[u] = list(u_ls)
u_i_dict
# Out:
# {0: [15825, 41241, 29131],
#  1: [14309, 52670, 34715, 7960, 10454, 11779, 51383],
#  2: [1939, 60262, 8368, 22437],
#  3: [44971, 5343, 53621, 9169],
#  4: [12739, 6649, 51541, 28769, 23794, 25783],
#  5: [5359, 28017, 52333],
#  6: [45984, 24858, 36933],
#  7: [41951, 33124, 39616, 14871],
#  8: [42989, 53669, 51479, 59186, 19653, 13113, 37670, 45587, 162],
#  9: [52520, 1461, 14194, 27891, 16995],
#  10: [2922, 42751, 21861],
#  11: [21459, 16005, 13624, 45030, 45036, 57255, 38418, 32524],
#  12: [5529, 48094, 47045, 51260, 34646, 13714],
#  13: [5614, 8774, 1378],
#  14: [2590,
#   28124,
#   23326,
#   12497,
#   51670,
#   31316,
#   33557,
#   53819,
#   60084,
#   1450,
#   57695,
#   62909,
#   21416,
#   11594,
#   38946,
#   21693],
#  15: [16389,
#   60124,
#   39610,
#   9396,
#   45814,
#   9705,
#   59147,
#   31388,
#   47494,
#   38536,
#   45702,
#   7428,
#   19946],
#  16: [60056, 54209, 36840],
#  17: [37963, 11767, 27627, 20280, 53644, 32719, 19523, 60139],
# ...

# %%
new_label = []
u_ids_sorted = sorted(u_i_dict.keys())

for u in u_ids_sorted:
    items = u_i_dict[u]
    n_items = len(items)
    if n_items < 10:
        tmp_ls = [0] * (n_items - 2) + [1] + [2]
    else:
        val_test_len = int(n_items * 0.2)
        train_len = n_items - val_test_len
        val_len = val_test_len // 2
        test_len = val_test_len - val_len
        tmp_ls = [0] * train_len + [1] * val_len + [2] * test_len
    new_label.extend(tmp_ls)

new_label[:40]
# Out:
# [0,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1,
#  2,
#  0,
#  0,
#  1,
#  2,
#  0,
#  0,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  1,
#  2,
#  0,
#  1,
#  2,
#  0,
#  1,
#  2,
#  0,
#  0,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0]

# %%
df['x_label'] = new_label
print(df.sort_values(by='user_id')[:20])
#df[:40]
# Out:
#          user_id  item_id  rating  x_label
# 482119         0    15825     5.0        0
# 482118         0    41241     5.0        1
# 482117         0    29131     5.0        2
# 968757         1    14309     5.0        0
# 968760         1    52670     5.0        0
# 968759         1    34715     5.0        0
# 968758         1     7960     5.0        0
# 968762         1    10454     5.0        0
# 968756         1    11779     4.0        1
# 968761         1    51383     5.0        2
# 1188435        2    22437     5.0        2
# 1188438        2     8368     5.0        1
# 1188436        2     1939     5.0        0
# 1188437        2    60262     5.0        0
# 718941         3    44971     5.0        0
# 718942         3     5343     5.0        0
# 718943         3    53621     4.0        1
# 718940         3     9169     5.0        2
# 1030621        4    23794     3.0        1
# 1030620        4    25783     5.0        2

# %%
df[df['user_id'] == 24]
# Out:
#         user_id  item_id  rating  x_label
# 340849       24    23792     2.0        0
# 340851       24    37993     2.0        1
# 340850       24    41079     5.0        2

# %%
df['x_label'].value_counts()
# Out:
# x_label
# 0    838141
# 2    212066
# 1    204234
# Name: count, dtype: int64

# %%
df.sort_values(by='item_id', ascending=True).tail(20)
# Out:
#         user_id  item_id  rating  x_label
# 748438   155990    62999     5.0        0
# 340882    51402    62999     4.0        0
# 739017   166170    62999     5.0        0
# 106035    39922    62999     5.0        0
# 399672    33826    62999     5.0        0
# 401503   146254    62999     5.0        0
# 605412   115269    62999     5.0        2
# 289695    88800    62999     5.0        0
# 485358   190703    62999     4.0        0
# 519857   146297    62999     5.0        0
# 223258   114751    62999     5.0        0
# 655356   166497    62999     5.0        2
# 224306    12291    62999     5.0        0
# 515144   181539    62999     4.0        0
# 475392    30031    62999     5.0        0
# 683424    84092    63000     4.0        0
# 519503    53305    63000     5.0        0
# 293959   149786    63000     5.0        0
# 294164    71684    63000     5.0        0
# 286514   115810    63000     5.0        0

# %%
df2 = pd.read_csv('../train_pre.csv')
df2.sort_values(by='item_id', ascending=True).tail(20)
# Out:
#         user_id  item_id  rating  x_label
# 475392    30031    62999     5.0        0
# 748438   155990    62999     5.0        2
# 223258   114751    62999     5.0        1
# 401503   146254    62999     5.0        1
# 605412   115269    62999     5.0        0
# 224306    12291    62999     5.0        1
# 399672    33826    62999     5.0        0
# 519857   146297    62999     5.0        2
# 739017   166170    62999     5.0        0
# 289695    88800    62999     5.0        0
# 655356   166497    62999     5.0        0
# 515144   181539    62999     4.0        1
# 340882    51402    62999     4.0        1
# 485358   190703    62999     4.0        0
# 106035    39922    62999     5.0        0
# 519503    53305    63000     5.0        0
# 683424    84092    63000     4.0        0
# 286514   115810    63000     5.0        1
# 294164    71684    63000     5.0        0
# 293959   149786    63000     5.0        0

# %%
#concatenated_df.to_csv('../kcore5_to_UI_new2_label.inter', index = False)

# %%
df.to_csv('../orignal_train.inter', index = False)
